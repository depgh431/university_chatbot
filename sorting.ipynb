# %%
import pandas as pd
data=pd.read_excel('final.xlsx')
df=pd.DataFrame(data)

# %%
df
# Out:
#      Unnamed: 0  index                                            Queries  \
# 0             0      0  Respected Sir,\n\nGood Afternoon, I would like...
# 1             1      2                                                  l
# 2             2      3                                      batch change
# 3             3      4                          I want to change my batch
# 4             4      5                                       batch Change
# ..          ...    ...                                                ...
# 580         580   1000                                     form is filled
# 581         581   1001  May I please know where the deadline for chang...
# 582         582   1002                                     regarding fees
# 583         583   1004  It's an online internship so I don't think tha...
# 584         584   1005  ICIE282M: Understanding Markets and Customers,...
#
#      cluster                                            Answers
# 0         18  Dear Student, you are requested to kindly refe...
# 1          2             Dear Student,  Kindly share the query.
# 2         18  Dear Student kimdly refer to the mail shared b...
# 3         18  Dear Student, kindly refer to the mail shared ...
# 4         18  Dear Student kindly refer to the mail shared b...
# ..       ...                                                ...
# 580        1  Dear Student,\n\nAs per your request your cour...
# 581        2  Yes, in the mail itself shared by registry dep...
# 582       20  Dear Student,\nFor any Query related to Financ...
# 583        2  Kindly share the requisition letter from the o...
# 584       10  Dear Student,\n\nyou can drop your course by f...
#
# [585 rows x 5 columns]

# %%
clusters=[]
for y in range(0,27):    
    clusters.append(0)
    for x in range(df.shape[0]):
        if df['cluster'][x]==y:
            l.append(df.iloc[x])
    clusters[y]=pd.DataFrame(l)
    l=[]

# %%
pattern=[]
responses=[]
for x in range(len(clusters)):
    pattern.append(clusters[x]['Queries'])
    responses.append(clusters[x]['Answers'])
